# %% [markdown]
# # Import Library dan Dataset

# %%
import numpy as np #library untuk operasi numerik
import pandas as pd #library untuk manipulasi dan analisis data

import matplotlib.pyplot as plt #library untuk visualisasi data
import seaborn as sns #library untuk visualisasi data statistik

# %%
df=pd.read_csv("D:\TELKOM UNIVERSITY\LAB\MBC\WORKSHOP\mobile_prices_2023.csv") #Membaca file csv sesuai Dir Path

df #Memanggila variabel/menampilkan dataframe
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1449065907.py:1: SyntaxWarning: invalid escape sequence '\T'
#   df=pd.read_csv("D:\TELKOM UNIVERSITY\LAB\MBC\WORKSHOP\mobile_prices_2023.csv") #Membaca file csv sesuai Dir Path
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
#            RAM ROM/Storage                     Back/Rare Camera  \
# 0     2 GB RAM   32 GB ROM                      8MP Dual Camera
# 1     4 GB RAM   64 GB ROM                           50MP + 2MP
# 2     4 GB RAM   64 GB ROM                 8MP Dual Rear Camera
# 3     4 GB RAM   64 GB ROM                50MP Dual Rear Camera
# 4     4 GB RAM   64 GB ROM                 8MP Dual Rear Camera
# ...        ...         ...                                  ...
# 1831  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1832  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1833  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1834  8 GB RAM  128 GB ROM    48MP + 8MP + 2MP + AI Lens Camera
# 1835  4 GB RAM   64 GB ROM  16MP + 5MP + 2MP + Low Light Sensor
#
#                       Front Camera   Battery  \
# 0                 5MP Front Camera  5000 mAh
# 1                 8MP Front Camera  5000 mAh
# 2                 5MP Front Camera  5000 mAh
# 3                 5MP Front Camera  5000 mAh
# 4                 5MP Front Camera  5000 mAh
# ...                            ...       ...
# 1831             16MP Front Camera  5000 mAh
# 1832             16MP Front Camera  5000 mAh
# 1833             16MP Front Camera  5000 mAh
# 1834  16MP + 8MP Dual Front Camera  4500 mAh
# 1835             32MP Front Camera  4000 mAh
#
#                                               Processor Price in INR  \
# 0     Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1                      Mediatek Dimensity 700 Processor      ₹11,999
# 2                                   Helio G36 Processor       ₹6,999
# 3                          Mediatek Helio G85 Processor       ₹7,749
# 4                                   Helio G36 Processor       ₹6,999
# ...                                                 ...          ...
# 1831                       MediaTek Helio G70 Processor      ₹14,999
# 1832                       MediaTek Helio G70 Processor      ₹14,999
# 1833                       MediaTek Helio G70 Processor      ₹14,999
# 1834                      MediaTek Helio G90T Processor      ₹18,999
# 1835                      Helio P22 (MTK6762) Processor      ₹10,999
#
#      Date of Scraping
# 0          2023-06-17
# 1          2023-06-17
# 2          2023-06-17
# 3          2023-06-17
# 4          2023-06-17
# ...               ...
# 1831       2023-06-17
# 1832       2023-06-17
# 1833       2023-06-17
# 1834       2023-06-17
# 1835       2023-06-17
#
# [1836 rows x 11 columns]

# %% [markdown]
# ##### Untuk mengetahui dimensi dataset (jumlah baris dan kolom), kita akan memeriksa shape-nya.

# %%
df.shape #Shape=Dimensi Data (jumlah baris dan kolom)
# Out:
# (1836, 11)

# %% [markdown]
# #### Kita perlu memastikan tipe data setiap kolom pada dataset sudah sesuai dengan format nilainya.

# %%
# Menampilkan informasi ringkas tentang DataFrame, termasuk jumlah baris, nama kolom, tipe data, dan jumlah nilai non-null.
df.info() 

# Menampilkan nama-nama kolom yang ada pada DataFrame.
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836 entries, 0 to 1835
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Phone Name         1836 non-null   object
#  1   Rating ?/5         1836 non-null   float64
#  2   Number of Ratings  1836 non-null   object
#  3   RAM                1836 non-null   object
#  4   ROM/Storage        1662 non-null   object
#  5   Back/Rare Camera   1827 non-null   object
#  6   Front Camera       1435 non-null   object
#  7   Battery            1826 non-null   object
#  8   Processor          1781 non-null   object
#  9   Price in INR       1836 non-null   object
#  10  Date of Scraping   1836 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 157.9+ KB
# Index(['Phone Name', 'Rating ?/5', 'Number of Ratings', 'RAM', 'ROM/Storage',
#        'Back/Rare Camera', 'Front Camera', 'Battery', 'Processor',
#        'Price in INR', 'Date of Scraping'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
df.duplicated().sum() # Menghitung jumlah baris duplikat dalam DataFrame.
# Out:
# 69

# %% [markdown]
# ##### Menampilkan baris duplikat

# %%
df[df.duplicated(keep=False)] # keep=False untuk menampilkan semua duplikat
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 45               POCO C31 (Shadow Gray, 64 GB)         4.3          2,22,992
# 50               POCO C31 (Shadow Gray, 64 GB)         4.3          2,22,992
# 94                     POCO M3 (Yellow, 64 GB)         4.3          1,25,650
# 95                 POCO M2 (Slate Blue, 64 GB)         4.4          4,09,478
# 96                     POCO M3 (Yellow, 64 GB)         4.3          1,25,650
# ...                                        ...         ...               ...
# 1740  Infinix NOTE 12i (Metaverse Blue, 64 GB)         4.2             5,955
# 1763  Infinix Smart 6 (Light Sea Green, 64 GB)         4.3            32,464
# 1764  Infinix Smart 6 (Light Sea Green, 64 GB)         4.3            32,464
# 1811   Infinix Smart 5 (Obsidian Black, 32 GB)         4.3          1,07,450
# 1815   Infinix Smart 5 (Obsidian Black, 32 GB)         4.3          1,07,450
#
#            RAM ROM/Storage         Back/Rare Camera      Front Camera  \
# 45    4 GB RAM   64 GB ROM         13MP + 2MP + 2MP  5MP Front Camera
# 50    4 GB RAM   64 GB ROM         13MP + 2MP + 2MP  5MP Front Camera
# 94    4 GB RAM   64 GB ROM         48MP + 2MP + 2MP  8MP Front Camera
# 95    6 GB RAM   64 GB ROM   13MP + 8MP + 5MP + 2MP  8MP Front Camera
# 96    4 GB RAM   64 GB ROM         48MP + 2MP + 2MP  8MP Front Camera
# ...        ...         ...                      ...               ...
# 1740  4 GB RAM   64 GB ROM      50 MP + 2 MP + QVGA  8MP Front Camera
# 1763  2 GB RAM   64 GB ROM        8 MP + Depth Lens  5MP Front Camera
# 1764  2 GB RAM   64 GB ROM        8 MP + Depth Lens  5MP Front Camera
# 1811  2 GB RAM   32 GB ROM  13MP + Low Light Sensor  8MP Front Camera
# 1815  2 GB RAM   32 GB ROM  13MP + Low Light Sensor  8MP Front Camera
#
#        Battery                          Processor Price in INR  \
# 45    5000 mAh       MediaTek Helio G35 Processor       ₹8,999
# 50    5000 mAh       MediaTek Helio G35 Processor       ₹8,999
# 94    6000 mAh  Qualcomm Snapdragon 662 Processor      ₹11,999
# 95    5000 mAh       MediaTek Helio G80 Processor      ₹12,999
# 96    6000 mAh  Qualcomm Snapdragon 662 Processor      ₹11,999
# ...        ...                                ...          ...
# 1740  5000 mAh       Mediatek Helio G85 Processor      ₹10,499
# 1763  5000 mAh       Mediatek Helio A22 Processor       ₹6,999
# 1764  5000 mAh       Mediatek Helio A22 Processor       ₹6,999
# 1811  6000 mAh       MediaTek Helio G25 Processor       ₹7,499
# 1815  6000 mAh       MediaTek Helio G25 Processor       ₹7,499
#
#      Date of Scraping
# 45         2023-06-17
# 50         2023-06-17
# 94         2023-06-17
# 95         2023-06-17
# 96         2023-06-17
# ...               ...
# 1740       2023-06-17
# 1763       2023-06-17
# 1764       2023-06-17
# 1811       2023-06-17
# 1815       2023-06-17
#
# [138 rows x 11 columns]

# %% [markdown]
# ##### Penanganan Data Duplikat
#
# Kodingan sebelumnya menunjukkan adanya 138 baris duplikat dalam dataset.  Data duplikat dapat berdampak negatif pada model Machine Learning, seperti:
#
# * **Bias:** Model cenderung memberikan bobot lebih pada data yang muncul berulang.
# * **Overfitting:** Model terlalu menyesuaikan diri dengan data latih, termasuk data duplikat, sehingga kinerjanya buruk pada data baru.
#
# Untuk mengatasi hal ini, kita akan menghapus baris duplikat menggunakan  `df = df.drop_duplicates()`. Fungsi ini akan menghapus semua baris duplikat kecuali satu, sehingga dataset menjadi lebih bersih dan representatif.

# %%
df = df.drop_duplicates() # Menghapus baris duplikat dari DataFrame.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Mengecek Data Null atau nilai yang hilang (bukan nol)

# %%
df.isnull().sum() #Menghitung jumlah nilai null (missing values) pada setiap kolom DataFrame.
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# RAM                    0
# ROM/Storage          162
# Back/Rare Camera       8
# Front Camera         381
# Battery                9
# Processor             49
# Price in INR           0
# Date of Scraping       0
# dtype: int64

# %%
# Menampilkan DataFrame yang memiliki nilai Null / NaN  
df[df.isnull().any(axis=1)]  # axis=1 untuk  memeriksa kolom pada setiap baris sedangkan axis=0 memeriksa baris pada setiap kolom.
# Out:
#                                        Phone Name  Rating ?/5  \
# 148    realme narzo 50i Prime (Mint Green, 32 GB)         4.2
# 159         realme Narzo N55 (Prime Blue, 128 GB)         4.3
# 169        realme Narzo N55 (Prime Black, 128 GB)         4.3
# 198    realme NARZO 50A PRIME (FLASH BLUE, 64 GB)         4.1
# 202   realme Narzo 50A Prime (Flash Blue, 128 GB)         4.1
# ...                                           ...         ...
# 1681                        Alcatel ONE TOUCH 506         3.0
# 1683   Alcatel One Touch Glory 2T (White, 100 MB)         4.1
# 1684                                Alcatel OT808         4.0
# 1685                       Alcatel ONE TOUCH 813D         4.5
# 1687       Alcatel Flash 2 (Volcanic Grey, 16 GB)         3.9
#
#      Number of Ratings         RAM            ROM/Storage  Back/Rare Camera  \
# 148                127    3 GB RAM              32 GB ROM   8MP Rear Camera
# 159                359    6 GB RAM             128 GB ROM  64MP Rear Camera
# 169                359    6 GB RAM             128 GB ROM  64MP Rear Camera
# 198              1,238    4 GB RAM              64 GB ROM  50MP Rear Camera
# 202              1,238    4 GB RAM             128 GB ROM  50MP Rear Camera
# ...                ...         ...                    ...               ...
# 1681                 5    2 MB ROM                    NaN   2MP Rear Camera
# 1683                21  256 MB RAM             100 MB ROM   2MP Rear Camera
# 1684                22   80 MB ROM   Expandable Upto 8 GB   2MP Rear Camera
# 1685                22   50 MB ROM  Expandable Upto 16 GB   2MP Rear Camera
# 1687               568    2 GB RAM              16 GB ROM  13MP Rear Camera
#
#      Front Camera   Battery  \
# 148           NaN  5000 mAh
# 159           NaN  5000 mAh
# 169           NaN  5000 mAh
# 198           NaN  5000 mAh
# 202           NaN  5000 mAh
# ...           ...       ...
# 1681          NaN   650 mAh
# 1683          NaN  1400 mAh
# 1684          NaN   850 mAh
# 1685          NaN  1000 mAh
# 1687          NaN  3000 mAh
#
#                                               Processor Price in INR  \
# 148                 Unisoc Tiger T612 (12 nm) Processor       ₹7,076
# 159   1 Year Domestic Warranty for Phone and 6 Month...      ₹13,399
# 169   1 Year Domestic Warranty for Phone and 6 Month...      ₹13,589
# 198        1 YEAR ON MOBILE AND 6 MONTHS FOR ACCESORIES      ₹11,300
# 202                            12 Months Brand Warranty      ₹11,979
# ...                                                 ...          ...
# 1681       1 Year for Mobile & 6 Months for Accessories       ₹2,490
# 1683       1 Year for Mobile & 6 Months for Accessories       ₹4,350
# 1684       1 Year for Mobile & 6 Months for Accessories       ₹6,450
# 1685       1 Year for Mobile & 6 Months for Accessories       ₹4,990
# 1687                                   MT6753 Processor       ₹9,999
#
#      Date of Scraping
# 148        2023-06-17
# 159        2023-06-17
# 169        2023-06-17
# 198        2023-06-17
# 202        2023-06-17
# ...               ...
# 1681       2023-06-17
# 1683       2023-06-17
# 1684       2023-06-17
# 1685       2023-06-17
# 1687       2023-06-17
#
# [515 rows x 11 columns]

# %% [markdown]
# ### Penanganan Nilai Null
#
# Pada dataset ini, nilai null dilambangkan dengan "NaN".  Setelah mempertimbangkan karakteristik dataset, diputuskan bahwa baris dengan nilai null akan dihapus daripada diisi. Berikut alasannya:
#
# * Beberapa kolom, seperti "Front Camera", memiliki persentase nilai null yang tinggi. Mengisi nilai null pada kolom tersebut dapat  menimbulkan bias pada data.
# * Variabel-variabel seperti RAM, ROM, dan spesifikasi kamera memiliki nilai yang spesifik. Mengisi nilai null dengan rata-rata atau nilai lain  dapat mengaburkan makna dan  mempengaruhi analisis.
# * Dataset ini memiliki lebih dari 1.800 baris. Menghapus sebagian kecil baris yang mengandung nilai null tidak akan mengurangi jumlah data secara signifikan.
# * Mengisi nilai null, terutama pada variabel yang saling terkait (misalnya, harga dan spesifikasi), dapat mengganggu  hubungan antar variabel dan  menghasilkan analisis yang kurang akurat.
#
# Oleh karena itu, menghapus baris dengan nilai null merupakan strategi yang lebih tepat untuk menjaga kualitas dan integritas data.

# %%
df = df.dropna() # Menghapus semua baris yang mengandung nilai null
df.isnull().sum() # Menghitung jumlah nilai null pada setiap kolom setelah dihapus
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# Date of Scraping     0
# dtype: int64

# %%
# Mengubah nama beberapa kolom pada DataFrame.
df.rename(columns={'Phone Name': 'Nama HP','Rating ?/5':'Rating','Number of Ratings':'Banyak Rating' ,'ROM/Storage': 'ROM', 'Back/Rare Camera': 'Back Camera'}, inplace=True)
# Menampilkan informasi baru dari DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1252 entries, 0 to 1835
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nama HP           1252 non-null   object
#  1   Rating            1252 non-null   float64
#  2   Banyak Rating     1252 non-null   object
#  3   RAM               1252 non-null   object
#  4   ROM               1252 non-null   object
#  5   Back Camera       1252 non-null   object
#  6   Front Camera      1252 non-null   object
#  7   Battery           1252 non-null   object
#  8   Processor         1252 non-null   object
#  9   Price in INR      1252 non-null   object
#  10  Date of Scraping  1252 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 117.4+ KB

# %% [markdown]
# # EDA / Pre-processing

# %%
drop_date = ['Date of Scraping'] # Menentukan kolom yang akan dihapus.
df.drop(columns=drop_date, inplace=True) # Menghapus kolom 'Date of Scraping' dari DataFrame.

# %% [markdown]
# ##### Alasan Menghapus Kolom 'Date of Scraping'
#
# * Informasi tanggal pengambilan data tidak memiliki pengaruh signifikan terhadap analisis harga atau spesifikasi ponsel.
# * Menghapus kolom yang tidak relevan membantu menyederhanakan dataset tanpa menghilangkan informasi penting. Hal ini dapat meningkatkan efisiensi komputasi

# %% [markdown]
# ### Kita akan mengecek nilai dan melakukan preprocess pada setiap kolom.

# %%
df['Nama HP'].unique() #Melihat daftar unik nama HP.
# Out:
# array(['POCO C50 (Royal Blue, 32 GB)', 'POCO M4 5G (Cool Blue, 64 GB)',
#        'POCO C51 (Royal Blue, 64 GB)', ...,
#        'Infinix Note 7 (Aether Black, 64 GB)',
#        'Infinix Zero 8i (Silver Diamond, 128 GB)',
#        'Infinix S5 (Quetzal Cyan, 64 GB)'], dtype=object)

# %% [markdown]
# #### Preprocessing Kolom Nama HP
#
# Kolom `Nama HP` di-preprocess untuk mengambil **hanya merek ponsel (string pertama)**. Karena:
#
# * Setiap merek memiliki banyak tipe ponsel dengan spesifikasi yang berbeda-beda. Informasi tipe ponsel  dianggap tidak relevan untuk analisis ini.
# * Informasi mengenai storage (ROM) sudah tersedia di kolom `ROM`.
# * Warna ponsel tidak memiliki pengaruh signifikan terhadap prediksi harga.

# %%
df['Nama HP'] = df['Nama HP'].str.split().str[0] # Mengambil string pertama dari setiap nilai pada kolom 'Nama HP'.
df['Nama HP'] # Menampilkan kolom 'Nama HP' setelah diproses.
# Out:
# 0          POCO
# 1          POCO
# 2          POCO
# 3          POCO
# 4          POCO
#          ...
# 1831    Infinix
# 1832    Infinix
# 1833    Infinix
# 1834    Infinix
# 1835    Infinix
# Name: Nama HP, Length: 1252, dtype: object

# %%
df.dtypes # Menampilkan tipe data dari setiap kolom pada DataFrame.
# Out:
# Nama HP           object
# Rating           float64
# Banyak Rating     object
# RAM               object
# ROM               object
# Back Camera       object
# Front Camera      object
# Battery           object
# Processor         object
# Price in INR      object
# dtype: object

# %%
df['Banyak Rating'] #Menampilkan kolom 'Banyak Rating'
# Out:
# 0       33,561
# 1       77,128
# 2       15,175
# 3       22,621
# 4       15,175
#          ...
# 1831    25,582
# 1832    25,582
# 1833    25,582
# 1834     7,117
# 1835    15,701
# Name: Banyak Rating, Length: 1252, dtype: object

# %% [markdown]
# #### Preprocessing Kolom 'Number of Ratings'
#
# Kolom `Number of Ratings` saat ini bertipe data `object` dan menggunakan koma (,) sebagai pemisah ribuan. Maka kita perlu melakukan:
#
# 1. Menghapus koma (,).
# 2. Mengubah tipe data menjadi integer.

# %%
# Membersihkan dan mengubah tipe data kolom 'Banyak Rating'.
df['Banyak Rating'] = df['Banyak Rating'].str.replace(',', '').astype(int)

# %%
# Menghitung frekuensi kemunculan setiap nilai unik pada kolom 'RAM'.
df['RAM'].value_counts()
# Out:
# RAM
# 4 GB RAM      341
# 8 GB RAM      338
# 6 GB RAM      265
# 3 GB RAM      153
# 2 GB RAM       90
# 12 GB RAM      46
# 1 GB RAM       12
# 512 MB RAM      4
# 8 MB RAM        1
# 16 MB RAM       1
# 1.5 GB RAM      1
# Name: count, dtype: int64

# %% [markdown]
# #### Preprocessing Kolom 'RAM'
#
# Menghapus nilai RAM seperti "1 GB RAM", "512 MB RAM", dan lainnya dilakukan karena:
# - RAM kecil jarang ditemukan pada ponsel saat ini

# %%
# Daftar nama RAM yang ingin dihapus
ram_to_remove = ["1 GB RAM", "512 MB RAM", "8 MB RAM", "16 MB RAM", "1.5 GB RAM"]

# %%
# Menghapus baris yang memiliki RAM dalam ram_to_remove
df = df[~df['RAM'].isin(ram_to_remove)]

# %%
df['RAM'].value_counts()
# Out:
# RAM
# 4 GB RAM     341
# 8 GB RAM     338
# 6 GB RAM     265
# 3 GB RAM     153
# 2 GB RAM      90
# 12 GB RAM     46
# Name: count, dtype: int64

# %%
# Membersihkan dan mengubah tipe data kolom 'RAM'.
df['RAM'] = df['RAM'].str.split().str[0]  # Mengambil angka dari nilai RAM
df['RAM'].fillna(0, inplace=True)  # Mengisi nilai null dengan 0
df['RAM'] = df['RAM'].astype(int)  # Mengubah tipe data menjadi integer
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\2803019780.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RAM'].fillna(0, inplace=True)  # Mengisi nilai null dengan 0

# %%
df #Menampilkan DataFrame
# Out:
#       Nama HP  Rating  Banyak Rating  RAM         ROM  \
# 0        POCO     4.2          33561    2   32 GB ROM
# 1        POCO     4.2          77128    4   64 GB ROM
# 2        POCO     4.3          15175    4   64 GB ROM
# 3        POCO     4.2          22621    4   64 GB ROM
# 4        POCO     4.3          15175    4   64 GB ROM
# ...       ...     ...            ...  ...         ...
# 1831  Infinix     4.3          25582    4   64 GB ROM
# 1832  Infinix     4.3          25582    4   64 GB ROM
# 1833  Infinix     4.3          25582    4   64 GB ROM
# 1834  Infinix     4.2           7117    8  128 GB ROM
# 1835  Infinix     4.3          15701    4   64 GB ROM
#
#                               Back Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# 1                              50MP + 2MP              8MP Front Camera
# 2                    8MP Dual Rear Camera              5MP Front Camera
# 3                   50MP Dual Rear Camera              5MP Front Camera
# 4                    8MP Dual Rear Camera              5MP Front Camera
# ...                                   ...                           ...
# 1831    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1832    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1833    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1834    48MP + 8MP + 2MP + AI Lens Camera  16MP + 8MP Dual Front Camera
# 1835  16MP + 5MP + 2MP + Low Light Sensor             32MP Front Camera
#
#        Battery                                          Processor Price in INR
# 0     5000 mAh  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1     5000 mAh                   Mediatek Dimensity 700 Processor      ₹11,999
# 2     5000 mAh                                Helio G36 Processor       ₹6,999
# 3     5000 mAh                       Mediatek Helio G85 Processor       ₹7,749
# 4     5000 mAh                                Helio G36 Processor       ₹6,999
# ...        ...                                                ...          ...
# 1831  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1832  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1833  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1834  4500 mAh                      MediaTek Helio G90T Processor      ₹18,999
# 1835  4000 mAh                      Helio P22 (MTK6762) Processor      ₹10,999
#
# [1233 rows x 10 columns]

# %%
# Menampilkan frekuensi kemunculan setiap nilai unik pada kolom 'ROM'.
df['ROM'].value_counts()
# Out:
# ROM
# 128 GB ROM    541
# 64 GB ROM     355
# 32 GB ROM     179
# 256 GB ROM    126
# 16 GB ROM      26
# 512 GB ROM      4
# 8 GB ROM        2
# Name: count, dtype: int64

# %%
# Daftar nama ROM yang ingin dihapus
rom_to_remove = ["8 GB ROM"]

# %%
# Menghapus baris yang memiliki RAM dalam ram_to_remove
df = df[~df['ROM'].isin(rom_to_remove)]

# %%
df['ROM'] = df['ROM'].str.split().str[0]  # Mengambil angka dari nilai ROM
df['ROM'] = df['ROM'].astype(int)  # Mengubah tipe data menjadi integer
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1768505869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ROM'] = df['ROM'].str.split().str[0]  # Mengambil angka dari nilai ROM
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1768505869.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ROM'] = df['ROM'].astype(int)  # Mengubah tipe data menjadi integer

# %%
df['ROM'].value_counts()
# Out:
# ROM
# 128    541
# 64     355
# 32     179
# 256    126
# 16      26
# 512      4
# Name: count, dtype: int64

# %%
df #Menampilkan DataFrame
# Out:
#       Nama HP  Rating  Banyak Rating  RAM  ROM  \
# 0        POCO     4.2          33561    2   32
# 1        POCO     4.2          77128    4   64
# 2        POCO     4.3          15175    4   64
# 3        POCO     4.2          22621    4   64
# 4        POCO     4.3          15175    4   64
# ...       ...     ...            ...  ...  ...
# 1831  Infinix     4.3          25582    4   64
# 1832  Infinix     4.3          25582    4   64
# 1833  Infinix     4.3          25582    4   64
# 1834  Infinix     4.2           7117    8  128
# 1835  Infinix     4.3          15701    4   64
#
#                               Back Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# 1                              50MP + 2MP              8MP Front Camera
# 2                    8MP Dual Rear Camera              5MP Front Camera
# 3                   50MP Dual Rear Camera              5MP Front Camera
# 4                    8MP Dual Rear Camera              5MP Front Camera
# ...                                   ...                           ...
# 1831    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1832    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1833    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1834    48MP + 8MP + 2MP + AI Lens Camera  16MP + 8MP Dual Front Camera
# 1835  16MP + 5MP + 2MP + Low Light Sensor             32MP Front Camera
#
#        Battery                                          Processor Price in INR
# 0     5000 mAh  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1     5000 mAh                   Mediatek Dimensity 700 Processor      ₹11,999
# 2     5000 mAh                                Helio G36 Processor       ₹6,999
# 3     5000 mAh                       Mediatek Helio G85 Processor       ₹7,749
# 4     5000 mAh                                Helio G36 Processor       ₹6,999
# ...        ...                                                ...          ...
# 1831  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1832  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1833  5000 mAh                       MediaTek Helio G70 Processor      ₹14,999
# 1834  4500 mAh                      MediaTek Helio G90T Processor      ₹18,999
# 1835  4000 mAh                      Helio P22 (MTK6762) Processor      ₹10,999
#
# [1231 rows x 10 columns]

# %%
# Menampilkan frekuensi kemunculan setiap nilai unik pada kolom 'Back Camera'.
df['Back Camera'].value_counts()
# Out:
# Back Camera
# 13MP + 2MP                             77
# 64MP + 8MP + 2MP                       76
# 50MP + 2MP + 2MP                       76
# 50MP + 2MP                             69
# 13MP Rear Camera                       55
#                                        ..
# 16MP + 5MP + 8MP                        1
# 48MP + 2MP + 16MP + 8MP                 1
# 50MP + 50MP + 12MP                      1
# 12.2MP Rear Camera                      1
# 16MP + 5MP + 2MP + Low Light Sensor     1
# Name: count, Length: 145, dtype: int64

# %% [markdown]
# #### Preprocessing Kolom `Back Camera`
#
# Kolom `Back Camera`  memiliki data yang beragam. Untuk menyederhanakannya, kita akan fokus pada **ukuran kamera dengan megapixel terbesar** dan menambahkan kolom baru untuk **jumlah kamera belakang**.
#
# Dengan melakukan:
#
#    - Mengambil angka dari nilai `Back Camera` yang menunjukkan ukuran kamera utama (dalam MP).
#    - Membersihkan dan menstandarisasi nilai, termasuk menghapus "MP" atau "Mp" dan mengganti beberapa nilai (misalnya, "12.2" menjadi "12").
#    - Mengubah tipe data menjadi integer.

# %%
# Membuat kolom baru 'Size Cam Blkg' yang berisi ukuran kamera belakang utama (dalam MP).
df['Size Cam Blkg'] = df['Back Camera'].str.split().str[0].str.replace('MP', '').str.replace('Mp', '')
df['Size Cam Blkg'] = df['Size Cam Blkg'].str.replace('12.2','12').str.replace('12.3','12').str.replace('0.3','1').astype(int)

# Fungsi untuk menghitung jumlah kamera belakang berdasarkan string.
def hitung_cam(string_cam):
    if "Dual" in string_cam:
        return 2
    else:
        hitung_plus = string_cam.count('+')
        return hitung_plus + 1

# Membuat kolom baru 'Total Cam Blkg' yang berisi jumlah kamera belakang.
df['Total Cam Blkg'] = df['Back Camera'].apply(lambda x: hitung_cam(x))

# Menghapus kolom 'Back Camera' yang asli.
drpro = ['Back Camera']
df.drop(columns=drpro, inplace=True)
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1526796684.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Blkg'] = df['Back Camera'].str.split().str[0].str.replace('MP', '').str.replace('Mp', '')
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1526796684.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Blkg'] = df['Size Cam Blkg'].str.replace('12.2','12').str.replace('12.3','12').str.replace('0.3','1').astype(int)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1526796684.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Cam Blkg'] = df['Back Camera'].apply(lambda x: hitung_cam(x))
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\1526796684.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=drpro, inplace=True)

# %%
df #Menampilkan DataFrame
# Out:
#       Nama HP  Rating  Banyak Rating  RAM  ROM                  Front Camera  \
# 0        POCO     4.2          33561    2   32              5MP Front Camera
# 1        POCO     4.2          77128    4   64              8MP Front Camera
# 2        POCO     4.3          15175    4   64              5MP Front Camera
# 3        POCO     4.2          22621    4   64              5MP Front Camera
# 4        POCO     4.3          15175    4   64              5MP Front Camera
# ...       ...     ...            ...  ...  ...                           ...
# 1831  Infinix     4.3          25582    4   64             16MP Front Camera
# 1832  Infinix     4.3          25582    4   64             16MP Front Camera
# 1833  Infinix     4.3          25582    4   64             16MP Front Camera
# 1834  Infinix     4.2           7117    8  128  16MP + 8MP Dual Front Camera
# 1835  Infinix     4.3          15701    4   64             32MP Front Camera
#
#        Battery                                          Processor  \
# 0     5000 mAh  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...
# 1     5000 mAh                   Mediatek Dimensity 700 Processor
# 2     5000 mAh                                Helio G36 Processor
# 3     5000 mAh                       Mediatek Helio G85 Processor
# 4     5000 mAh                                Helio G36 Processor
# ...        ...                                                ...
# 1831  5000 mAh                       MediaTek Helio G70 Processor
# 1832  5000 mAh                       MediaTek Helio G70 Processor
# 1833  5000 mAh                       MediaTek Helio G70 Processor
# 1834  4500 mAh                      MediaTek Helio G90T Processor
# 1835  4000 mAh                      Helio P22 (MTK6762) Processor
#
#      Price in INR  Size Cam Blkg  Total Cam Blkg
# 0          ₹5,649              8               2
# 1         ₹11,999             50               2
# 2          ₹6,999              8               2
# 3          ₹7,749             50               2
# 4          ₹6,999              8               2
# ...           ...            ...             ...
# 1831      ₹14,999             48               4
# 1832      ₹14,999             48               4
# 1833      ₹14,999             48               4
# 1834      ₹18,999             48               4
# 1835      ₹10,999             16               4
#
# [1231 rows x 11 columns]

# %%
# Menampilkan frekuensi kemunculan setiap nilai unik pada kolom 'Front Camera'.
df['Front Camera'].value_counts()
# Out:
# Front Camera
# 16MP Front Camera               327
# 8MP Front Camera                298
# 5MP Front Camera                248
# 32MP Front Camera                97
# 13MP Front Camera                69
# 20MP Front Camera                56
# 20MP + 2MP Dual Front Camera     14
# 50MP Front Camera                14
# 12MP Front Camera                13
# 32MP + 8MP Dual Front Camera     12
# 44MP Front Camera                11
# 10.8MP Front Camera               9
# 10MP Front Camera                 8
# 50MP + 8MP Dual Front Camera      8
# 2MP Front Camera                  7
# 25MP Front Camera                 6
# 60MP Front Camera                 5
# 44MP + 2MP Dual Front Camera      5
# 16MP + 2MP Dual Front Camera      4
# 24MP Front Camera                 3
# 4MP Front Camera                  3
# 60 MP with OIS                    3
# 16MP + 8MP Dual Front Camera      3
# 32MP + 2MP Dual Front Camera      2
# 8MP + 2MP Dual Front Camera       2
# 16MP Dual Front Camera            2
# 8MP + 8MP Dual Front Camera       1
# 13MP + 5MP Dual Front Camera      1
# Name: count, dtype: int64

# %% [markdown]
# #### Preprocessing Kolom `Front Camera`
#
# Pada kolom `Front Camera`, kita akan melakukan _preprocessing_ serupa dengan kolom `Back Camera`.  Informasi yang paling penting adalah **ukuran kamera depan dengan megapixel terbesar** dan **jumlah kamera depan**.
#
# Kita melakukan:
#
#    - Mengambil angka dari nilai `Front Camera` yang menunjukkan ukuran kamera utama (dalam MP).
#    - Membersihkan dan menstandarisasi nilai, termasuk menghapus "MP" atau "Mp" dan mengganti beberapa nilai (misalnya, "10.8" menjadi "11").
#    - Mengisi nilai null dengan 0.
#    - Mengubah tipe data menjadi integer.

# %%
# Membuat kolom baru 'Size Cam Dpn' yang berisi ukuran kamera depan (dalam MP).
df['Size Cam Dpn'] = df['Front Camera'].str.split().str[0].str.replace('MP', '').str.replace('Mp', '')
df['Size Cam Dpn'] = df['Size Cam Dpn'].str.replace('10.8', '11').str.replace('0.3', '1').str.replace('1.6', '2').str.replace('1.3', '1')
df['Size Cam Dpn'].fillna(0, inplace=True)

# Mengubah tipe data kolom 'Size Cam Dpn' menjadi integer.
df['Size Cam Dpn'] = df['Size Cam Dpn'].astype(int)

# Fungsi untuk menghitung jumlah kamera depan berdasarkan string.
def hitung_camera(string_cam):
    if "Dual" in string_cam:
        return 2
    else:
        return 1  # Jika tidak ada "Dual", diasumsikan hanya 1 kamera depan

# Membuat kolom baru 'Total Cam Dpn' yang berisi jumlah kamera depan.
df['Total Cam Dpn'] = df['Front Camera'].apply(lambda x: hitung_camera(x))

# Menghapus kolom 'Front Camera' yang asli.
drpro = ['Front Camera']
df.drop(columns=drpro, inplace=True)
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Dpn'] = df['Front Camera'].str.split().str[0].str.replace('MP', '').str.replace('Mp', '')
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Dpn'] = df['Size Cam Dpn'].str.replace('10.8', '11').str.replace('0.3', '1').str.replace('1.6', '2').str.replace('1.3', '1')
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size Cam Dpn'].fillna(0, inplace=True)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Dpn'].fillna(0, inplace=True)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size Cam Dpn'] = df['Size Cam Dpn'].astype(int)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Cam Dpn'] = df['Front Camera'].apply(lambda x: hitung_camera(x))
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4275174135.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=drpro, inplace=True)

# %%
df #Menampilkan DataFrame
# Out:
#       Nama HP  Rating  Banyak Rating  RAM  ROM   Battery  \
# 0        POCO     4.2          33561    2   32  5000 mAh
# 1        POCO     4.2          77128    4   64  5000 mAh
# 2        POCO     4.3          15175    4   64  5000 mAh
# 3        POCO     4.2          22621    4   64  5000 mAh
# 4        POCO     4.3          15175    4   64  5000 mAh
# ...       ...     ...            ...  ...  ...       ...
# 1831  Infinix     4.3          25582    4   64  5000 mAh
# 1832  Infinix     4.3          25582    4   64  5000 mAh
# 1833  Infinix     4.3          25582    4   64  5000 mAh
# 1834  Infinix     4.2           7117    8  128  4500 mAh
# 1835  Infinix     4.3          15701    4   64  4000 mAh
#
#                                               Processor Price in INR  \
# 0     Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1                      Mediatek Dimensity 700 Processor      ₹11,999
# 2                                   Helio G36 Processor       ₹6,999
# 3                          Mediatek Helio G85 Processor       ₹7,749
# 4                                   Helio G36 Processor       ₹6,999
# ...                                                 ...          ...
# 1831                       MediaTek Helio G70 Processor      ₹14,999
# 1832                       MediaTek Helio G70 Processor      ₹14,999
# 1833                       MediaTek Helio G70 Processor      ₹14,999
# 1834                      MediaTek Helio G90T Processor      ₹18,999
# 1835                      Helio P22 (MTK6762) Processor      ₹10,999
#
#       Size Cam Blkg  Total Cam Blkg  Size Cam Dpn  Total Cam Dpn
# 0                 8               2             5              1
# 1                50               2             8              1
# 2                 8               2             5              1
# 3                50               2             5              1
# 4                 8               2             5              1
# ...             ...             ...           ...            ...
# 1831             48               4            16              1
# 1832             48               4            16              1
# 1833             48               4            16              1
# 1834             48               4            16              2
# 1835             16               4            32              1
#
# [1231 rows x 12 columns]

# %%
# Menampilkan nilai-nilai unik yang ada pada kolom 'Battery'.
df['Battery'].unique()
# Out:
# array(['5000 mAh', '4500 mAh', '4000 mAh', '5160 mAh', '6000 mAh',
#        '5065 mAh', '4200 mAh', '4300 mAh', '4230 mAh', '3300 mAh',
#        '3900 mAh', '4700 mAh', '3700 mAh', '3000 mAh', '7000 mAh',
#        '4800 mAh', '4015 mAh', '4025 mAh', '3400 mAh', '4350 mAh',
#        '4310 mAh', '3200 mAh', '4020 mAh', '4410 mAh', '4270 mAh',
#        '4926 mAh', '2915 mAh', '4600 mAh', '4030 mAh', '4050 mAh',
#        '4810 mAh', '4830 mAh', '4870 mAh', '4450 mAh', '3315 mAh',
#        '3225 mAh', '3260 mAh', '4250 mAh', '4520 mAh', '3080 mAh',
#        '3120 mAh', '4100 mAh', '4850 mAh', '3030 mAh', '3010 mAh',
#        '4820 mAh', '4780 mAh', '5300 mAh', '5050 mAh', '3060 mAh',
#        '4950 mAh', '4400 mAh', '4610 mAh', '4115 mAh', '3800 mAh',
#        '4085 mAh', '3340 mAh', '3450 mAh', '2200 mAh', '2610 mAh',
#        '3760 mAh', '3500 mAh', '5200 mAh'], dtype=object)

# %% [markdown]
# #### Preprocessing Kolom `Battery`
#
# Kolom `Battery` pada dataset ini memiliki nilai yang beragam dan sulit dipetakan secara langsung.  Oleh karena itu, kita akan melakukan _preprocessing_ dengan mengelompokkan kapasitas baterai secara manual.
#
# Berikut langkah-langkah _preprocessing_ yang dilakukan:
#
#    - Menghapus string "mAh" dari setiap nilai pada kolom `Battery`.
#    - Mengubah tipe data kolom `Battery` menjadi float.
#    - Mengelompokkan kapasitas baterai ke dalam rentang tertentu, seperti: 5000 mAh - 5499 mAh menjadi "5000" dan seterusnya...
#    - Mengubah tipe data kolom Battery menjadi integer.

# %%
# Membersihkan dan mengubah tipe data kolom 'Battery'.
df['Battery'] = df['Battery'].str.replace('mAh', '').astype(float)  # Menghapus 'mAh' dan mengubah ke float

# Fungsi untuk mengelompokkan kapasitas baterai.
def pilah_pro(pro):
    if 5000 <= pro < 5500:
        return '5000'
    elif 5500 <= pro < 6000:
        return '5500'
    elif 4000 <= pro < 4500:
        return '4000'
    elif 4500 <= pro < 5000:
        return '4500'
    elif 2000 <= pro < 2500:
        return '2000'
    elif 2500 <= pro < 3000:
        return '2500'
    elif 1000 <= pro < 1500:
        return '1000'
    elif 1500 <= pro < 1900:
        return '1500'

# Menerapkan fungsi 'pilah_pro' pada kolom 'Battery'.
df['Battery'] = df['Battery'].apply(pilah_pro)

# Mengisi nilai null dengan 0 dan mengubah tipe data menjadi integer.
df['Battery'].fillna(0, inplace=True)
df['Battery'] = df['Battery'].astype(int)
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\660244476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery'] = df['Battery'].str.replace('mAh', '').astype(float)  # Menghapus 'mAh' dan mengubah ke float
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\660244476.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery'] = df['Battery'].apply(pilah_pro)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\660244476.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Battery'].fillna(0, inplace=True)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\660244476.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery'].fillna(0, inplace=True)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\660244476.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery'] = df['Battery'].astype(int)

# %% [markdown]
# #### Preprocessing Kolom `Price in INR`
#
# Kolom `Price in INR` perlu dibersihkan dan diubah tipe datanya agar siap untuk analisis dan pemodelan.  Berikut alasannya:
#
# * **Menghapus simbol mata uang**:  Simbol rupee India (`₹`) tidak diperlukan dalam analisis numerik dan perlu dihapus.
# * **Menghapus pemisah ribuan**:  Karakter koma (`,`) yang digunakan sebagai pemisah ribuan juga perlu dihapus agar data dapat diubah menjadi tipe numerik.
# * **Mengubah tipe data**:  Tipe data `object` (string) perlu diubah menjadi `float` (bilangan desimal) agar  operasi matematika dan analisis statistik dapat dilakukan pada kolom `Price in INR`.

# %%
# Membersihkan dan mengubah tipe data kolom 'Price in INR'.
df['Price in INR'] = df['Price in INR'].str.replace('₹', '').str.replace(',', '').astype(float)
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\3462661110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price in INR'] = df['Price in INR'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
# Menampilkan nilai-nilai unik yang ada pada kolom 'Processor'.
df['Processor'].unique()
# Out:
# array(['Mediatek Helio A22 Processor, Upto 2.0 GHz Processor',
#        'Mediatek Dimensity 700 Processor', 'Helio G36 Processor',
#        'Mediatek Helio G85 Processor', 'Mediatek Helio G99 Processor',
#        'Mediatek Helio G96 Processor',
#        'Qualcomm Snapdragon 695 Processor',
#        'Mediatek Dimensity 810 Processor',
#        'Qualcomm Snapdragon 778G Processor',
#        'MediaTek Dimensity 700 Processor',
#        'Qualcomm Snapdragon 695 5G Processor',
#        'Qualcomm Snapdragon 7+ Gen 2 (4nm) Processor',
#        'MediaTek Helio G35 Processor',
#        'Qualcomm Snapdragon 730G Processor', 'MediaTek G35 Processor',
#        'Qualcomm Snapdragon 845 Processor',
#        'Qualcomm Snapdragon 870 Processor',
#        'Mediatek Helio G35 Processor', 'MediaTek Helio G80 Processor',
#        'Qualcomm Snapdragon 720G Processor',
#        'Qualcomm Snapdragon 860 Processor',
#        'Qualcomm Snapdragon 662 Processor',
#        'Qualcomm Snapdragon 732G Processor',
#        'MediaTek Dimensity 1200 Processor', 'Helio G88 Processor',
#        'Unisoc T612 Processor', 'Mediatek Helio G99 Octa Core Processor',
#        'Unisoc T612 processor Processor',
#        'Mediatek Dimensity 810 5G Processor',
#        'MediaTek Helio G85 Processor', 'Unisoc T610 Processor',
#        'Unisoc Tiger T616 Processor', 'SC9863A Processor',
#        'MediaTek Helio G95 Processor',
#        'Qualcomm Snapdragon 888 Processor',
#        'MediaTek Helio G96 Processor',
#        'MediaTek Dimensity 800U Processor', 'Octa-core Processor',
#        'Mediatek Dimensity 1080 5G Processor',
#        '1 Year Manufacturer Warranty for Phone and 6 Months Warranty for In-Box Accessories',
#        'Unisoc SC9863A/ Unisoc SC9863A1 Processor',
#        'Qualcomm Snapdragon 680 (SM6225) Processor',
#        'Qualcomm Snapdragon 855+ Processor',
#        'Mediatek Dimensity 920 Processor', 'Unisoc T618 Processor',
#        'MediaTek Dimensity 700 (MT6833) Processor',
#        'Snapdragon 720G Processor', 'Unisoc T610 Octa Core Processor',
#        'MediaTek Helio P60 Octa Core 2.0 GHz Processor',
#        'Qualcomm Snapdragon 680 Processor',
#        'MediaTek Helio G70 Processor', 'MediaTek Helio G90T Processor',
#        'Mediatek Helio P35 Processor', 'Exynos 850 Processor',
#        'Exynos 1330, Octa Core Processor',
#        'Qualcomm Snapdragon 750G Processor',
#        'MediaTek Helio P35 Processor',
#        'Qualcomm Snapdragon 8 Gen 1 Processor',
#        'SEC S5E8535 (Exynos 1330) Processor',
#        'Qualcomm Snapdragon 695 (SM6375) Processor',
#        'Qualcomm Snapdragon 888 Octa-Core Processor',
#        'Dimensity 1080, Octa Core Processor',
#        'Exynos 1380, Octa Core Processor', 'Octa-core(EXYNOS) Processor',
#        '1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories',
#        'Exynos Octa Core Processor',
#        'Exynos Octa Core Processor Processor',
#        'Qualcomm Snapdragon 8 Gen 2 Processor',
#        '1 Year of Device & 6 Months for In-Box Accessories',
#        'Dimensity 720 5G Processor', 'Exynos 9610 Processor',
#        'Exynos 1280 Processor', 'Unisoc UMS9230 Processor',
#        'Mediatek MT6765 Helio P35 (12nm) Processor',
#        '1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box',
#        'Octa Core Processor', 'Exynos 850 (S5E3830) Processor',
#        'MediaTek Helio G80 (MT6769V) Processor',
#        'Qualcomm Snapdragon 8+ Gen 1 Processor', 'Exynos 9810 Processor',
#        'MediaTek MT6739 Processor', 'Exynos 850 Octa Core Processor',
#        'Qualcomm Snapdragon 450 (SDM450-F01) Processor',
#        'Qualcomm SM7150 Processor', '1 Year',
#        'Qualcomm Snapdragon 450 Processor',
#        'Samsung Exynos 9 Octa 9611 Processor',
#        'MediaTek | MT6739WW quad core Processor', 'Exynos 9825 Processor',
#        'Qualcomm Snapdragon (SDM450-F01) Octa Core Processor',
#        'MediaTek Helio G35 (MT6765G) Processor',
#        'Exynos 7870 Octa Core 1.6 GHz Processor',
#        '1 Year Manufacturer Warranty',
#        'MediaTek Helio P35 (MT6765) Processor',
#        'Qualcomm SDM450-B01 Processor',
#        'Qualcomm SM6225 Snapdragon 680 4G (6 nm) Processor',
#        'Mediatek Dimensity 1300 Processor', 'MTK Helio G35 Processor',
#        '12 months', 'Mediatek Helio P22 Processor',
#        'Mediatek Helio G35 (MT6765) Processor',
#        'MediaTek Helio P35 Octa Core Processor',
#        'Mediatek Dimensity 9000+ Processor',
#        'MediaTek Helio P95 Processor',
#        'Qualcomm Snapdragon 460 Processor',
#        'Brand Warranty of 1 Year Available for Mobile Including Battery and 6 Months for Accessories',
#        'MTK P60 Octa Core 2.0 GHz Processor',
#        'MediaTek Helio P22 Processor', 'MediaTek Dimensity 900 Processor',
#        'MediaTek Dimensity 1000+ (MT6889) Processor',
#        'Mediatek MT6750T Octa Core 1.5 GHz Processor',
#        'Qualcomm Snapdragon 665 Processor', 'SDM710 Processor',
#        'Mediatek MT6763T Octa Core 2.5 GHz Processor',
#        'MTK MT6771V (P70) Processor', 'Google Tensor Processor',
#        'Google Tensor G2 Processor', 'Tensor G2 Processor',
#        'Qualcomm Snapdragon 845 64-bit Processor',
#        'Dimensity 6020 Processor', 'Snapdragon 695 Processor',
#        'Mediatek Dimensity 7200 5G Processor',
#        'Qualcomm Snapdragon 439 Processor',
#        'Mediatek Dimensity 900 Processor',
#        'Qualcomm Snapdragon 778G 5G Mobile Platform Processor',
#        'Mediatek G96 Processor', 'Dimensity 9200 Processor',
#        'Mediatek MT6769 Helio G70 Processor',
#        'Mediatek Dimensity 8200 Processor', 'MTK Dimensity 700 Processor',
#        'Mediatek Helio G70 Processor',
#        'Turbo Processor Snapdragon 695 Processor',
#        'MediaTek P22 Processor', 'MTK Helio P22 Processor',
#        'Mediatek Dimensity 1200 Processor',
#        'MediaTek P60 Octa Core 2.0 GHz Processor',
#        'Qualcomm Snapdragon 665 AIE Processor',
#        'Mediatek Dimensity 9000 Processor',
#        'Qualcomm Snapdragon 712 AIE Octa Core 2.3GHz Processor',
#        'Qualcomm Snapdragon 660 AIE Processor',
#        'Qualcomm Snapdragon 450 Octa Core 1.8 GHz Processor',
#        'Mediatek MT6750 Octa Core 1.5GHz Processor',
#        'Helio P35 Processor', 'MT6762 Octa Core (Helio P22) Processor',
#        'Qualcomm Snapdragon 626 Processor',
#        'Qualcomm Snapdragon 675AIE Processor',
#        'Qualcomm Snapdragon 675AIE Octa Core 2.0GHz Processor',
#        'Qualcomm Snapdragon 712 AIE Processor',
#        'Mediatek Dimensity 800U Processor', 'Snapdragon 439 Processor',
#        'Qualcomm Snapdragon 778G+ Processor',
#        'Qualcomm Snapdragon 865 Processor',
#        'Qualcomm Snapdragon 636 Processor',
#        'Qualcomm Snapdragon 625 Processor',
#        'MediaTek Helio G25 Processor',
#        'Qualcomm Snapdragon 425 1.4 GHz Processor',
#        'Qualcomm Snapdragon 730 Processor',
#        '2.0 GHz Mediatek P22 Octacore Processor',
#        'Mediatek Helio G25 Processor',
#        'Qualcomm Snapdragon 632 Processor',
#        'Qualcomm Snapdragon 625 64-bit Octa Core 2GHz Processor',
#        'Qualcomm Snapdragon 430 64-bit Octa Core 1.4GHz Processor',
#        'Qualcomm Snapdragon 650 64-bit Processor',
#        'Snapdragon 820 Kryo Processor',
#        '2nd-gen Snapdragon 615 64-bit octa-core Processor',
#        'Qualcomm Snapdragon 855 Processor',
#        'Qualcomm® Snapdragon™ 750G Processor',
#        'Qualcomm Snapdragon 835 Octa Core 2.5 GHz Processor',
#        'Qualcomm Snapdragon 625 64 bit Octa Core 2GHz Processor',
#        'Qualcomm Snapdragon 625 Octa Core 2 Ghz Processor',
#        'Qualcomm Snapdragon 675 Processor', 'Unisoc SC9863A Processor',
#        'Unisoc T606 Processor',
#        'Qualcomm Snapdragon 636 Octacore Processor',
#        'Octa Core Processor Processor', 'Spreadtrum SC9863A Processor',
#        'MediaTek Helio A22 Processor', 'MediaTek Helio P60 Processor',
#        'Mediatek Helio G37 Processor', 'Helio G85 Processor',
#        'Mediatek Dimensity 930 Processor', 'Dimensity 8020 Processor',
#        'UNISOC T700 Processor', 'Qualcomm Snapdragon 888 + Processor',
#        'Qualcomm Snapdragon 778G Plus Processor',
#        'Qualcomm Snapdragon 480 Pro Processor',
#        'Mediatek MTK6737 Quad Core 1.3Ghz Processor',
#        'Qualcomm Snapdragon 870 5G (SM8250-AC) Processor',
#        'Snapdragon 460 Processor', 'Qualcomm® Snapdragon™ 765G Processor',
#        '1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase',
#        'Qualcomm® Snapdragon™ 855 Plus Processor',
#        'Qualcomm® Snapdragon™ 855 Plus (Octa-core, 7nm, up to 2.96 GHz) , with Qualcomm AI Engine Processor',
#        'HiSilicon Kirin 710F AI Chipset with Dual-NPU Processor',
#        'HUAWEI Kirin 955 ARM Cortex-A72 64-bit + ARM Cortex-A53 64-bit Processor',
#        'HUAWEI Kirin 955 ARM Cortex-A72 64-bit + ARM Cortex-A53 64-bit Octa Core 2.5GHz Processor',
#        'Kirin 710 Processor',
#        'Qualcomm Snapdragon 810 v2.1 64-bit Processor',
#        'MTK6737 Processor', 'MSM8952 Processor',
#        'Brand Warranty of 18 Months Available for Mobile',
#        'MediaTek MTK Helio P25 Octa Core 2.5 GHz Processor',
#        'MTK8735 Processor', 'Qualcomm SDM710 Processor',
#        'MediaTek MT6735P 64-bit Processor',
#        'Qualcomm Snapdragon SDM450 Processor',
#        'Mediatek Helio P10 64-bit Octa Core 1.8GHz Processor',
#        'Qualcomm Snapdragon 820 Quad Core 2.15GHz Processor',
#        'Qualcomm SDM855 Processor', 'MediaTek P22 Octa Core Processor',
#        'Qualcomm Snapdragon 430 Octa Core 1.4GHz Processor',
#        'Unisoc Spreadtrum SC9863A1 Processor', 'G37 Processor',
#        'Spreadtrum \nSC9863A1 Processor', 'Mediatek Helio A22 Processor',
#        'Dimensity 810 Processor', 'Spreadtrum SC9863A1 Processor',
#        'MediaTek G37 Processor', 'Meditek Helio G37 Processor',
#        'MediaTek Helio G88 Processor', 'Mediatek G99 Processor',
#        'Mediatek Dimensity 1080 Processor', 'Unisoc T616 Processor',
#        'MediaTek Helio A20 Processor', 'UniSoc T610 Processor',
#        'Mediatek Helio G88 Processor', 'Helio P22 (MTK6762) Processor'],
#       dtype=object)

# %% [markdown]
# #### Preprocessing Kolom `Processor`
#
# Kolom `Processor` pada dataset ini mengandung informasi tentang prosesor yang digunakan oleh setiap ponsel. Namun, nilai pada kolom ini seringkali  beragam dan tidak terstandarisasi.
#
# Langkah-langkah _preprocessing_ yang dilakukan:
#
# - Mengambil kata pertama dari setiap nilai pada kolom `Processor`. Biasanya, kata pertama menunjukkan merek prosesor (misalnya, "Snapdragon", "Mediatek", "Exynos").

# %%
# Membuat kolom baru 'Upd_Processor' yang berisi merek prosesor.
df['Upd_Processor'] = df['Processor'].str.split().str[0]

# Fungsi untuk mengelompokkan merek prosesor.
def pilah_pro(pro):
    if pro == 'Qualcomm' or pro == 'Qualcomm®' or pro == 'Snapdragon' or pro == '2nd-gen':
        return 'Snapdragon'
    elif pro == 'Mediatek' or pro == 'MediaTek' or pro == 'Meditek' or pro == 'Helio':
        return 'Mediatek'
    elif pro == 'Octa-core(EXYNOS)' or pro == 'Exynos':
        return 'Exynos'
    elif pro == '1':
        return 'IOS'
    elif pro == 'HUAWEI' or pro =='Kirin' :
        return 'Huawei'
    elif pro == 'Google':
        return 'Google'
    else :
        return 'Other'

# Menerapkan fungsi 'pilah_pro' pada kolom 'Upd_Processor'.
df['Upd_Processor'] = df['Upd_Processor'].apply(pilah_pro)

# Menghapus kolom 'Processor' yang asli.
drpro = ['Processor']
df.drop(columns=drpro, inplace=True)

# Menampilkan frekuensi kemunculan setiap nilai unik pada kolom 'Upd_Processor'.
df['Upd_Processor'].value_counts()
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4075259609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Upd_Processor'] = df['Processor'].str.split().str[0]
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4075259609.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Upd_Processor'] = df['Upd_Processor'].apply(pilah_pro)
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\4075259609.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=drpro, inplace=True)
# Upd_Processor
# Mediatek      494
# Snapdragon    455
# Other         197
# Exynos         49
# IOS            21
# Google         11
# Huawei          4
# Name: count, dtype: int64

# %%
# Membuat plot batang (bar plot) dari frekuensi kemunculan setiap merek HP.
df['Nama HP'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Nama HP'>

# %%
# Membuat histogram dan kurva dari distribusi harga ponsel.
sns.distplot(df['Price in INR'])
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\432758903.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price in INR'])
# <Axes: xlabel='Price in INR', ylabel='Density'>

# %%
# Membuat plot batang (bar plot) dari frekuensi kemunculan setiap nilai RAM.
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RAM'>

# %%
# Membuat plot batang (bar plot) dari frekuensi kemunculan setiap nilai ROM.
df['ROM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ROM'>

# %%
# Membuat plot batang (bar plot) dari frekuensi kemunculan setiap merek prosesor.
df['Upd_Processor'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Upd_Processor'>

# %%
# Membuat bar plot yang menunjukkan rata-rata harga ponsel untuk setiap merek.
sns.barplot(x=df['Nama HP'], y=df['Price in INR'])

# Memutar label sumbu x agar tidak tumpang tindih.
plt.xticks(rotation='vertical')

# Menampilkan plot.
plt.show()

# %%
# Membuat bar plot yang menunjukkan rata-rata harga ponsel untuk setiap nilai RAM.
sns.barplot(x=df['RAM'], y=df['Price in INR'])

# Memutar label sumbu x agar tidak tumpang tindih.
plt.xticks(rotation='vertical')

# Menampilkan plot.
plt.show()

# %%
# Membuat histogram dan kurva estimasi kepadatan (KDE) dari distribusi logaritma harga ponsel.
sns.distplot(np.log(df['Price in INR']))
# Out:
# C:\Users\alfar\AppData\Local\Temp\ipykernel_11580\2549127033.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price in INR']))
# <Axes: xlabel='Price in INR', ylabel='Density'>

# %%
df.dtypes
# Out:
# Nama HP            object
# Rating            float64
# Banyak Rating       int32
# RAM                 int32
# ROM                 int32
# Battery             int32
# Price in INR      float64
# Size Cam Blkg       int32
# Total Cam Blkg      int64
# Size Cam Dpn        int32
# Total Cam Dpn       int64
# Upd_Processor      object
# dtype: object

# %%
# Menggunakan one-hot encoding untuk kolom objek
df_encoded = pd.get_dummies(df, columns=['Nama HP', 'Upd_Processor'], drop_first=True)

# Mengambil hanya kolom numerik dari DataFrame yang sudah di-encode
df_numerik = df_encoded.select_dtypes(include=['float64', 'int32', 'int64'])

# Membuat heatmap korelasi dengan ukuran yang lebih besar.
plt.figure(figsize=(12,10))  # Mengatur ukuran figure
sns.heatmap(df_numerik.corr(), annot=True, annot_kws={'size': 15}, cmap='coolwarm')  # Membuat heatmap dengan anotasi
plt.title('Heatmap Korelasi dengan Kolom Objek')
plt.show()

# %%
df
# Out:
#       Nama HP  Rating  Banyak Rating  RAM  ROM  Battery  Price in INR  \
# 0        POCO     4.2          33561    2   32     5000        5649.0
# 1        POCO     4.2          77128    4   64     5000       11999.0
# 2        POCO     4.3          15175    4   64     5000        6999.0
# 3        POCO     4.2          22621    4   64     5000        7749.0
# 4        POCO     4.3          15175    4   64     5000        6999.0
# ...       ...     ...            ...  ...  ...      ...           ...
# 1831  Infinix     4.3          25582    4   64     5000       14999.0
# 1832  Infinix     4.3          25582    4   64     5000       14999.0
# 1833  Infinix     4.3          25582    4   64     5000       14999.0
# 1834  Infinix     4.2           7117    8  128     4500       18999.0
# 1835  Infinix     4.3          15701    4   64     4000       10999.0
#
#       Size Cam Blkg  Total Cam Blkg  Size Cam Dpn  Total Cam Dpn Upd_Processor
# 0                 8               2             5              1      Mediatek
# 1                50               2             8              1      Mediatek
# 2                 8               2             5              1      Mediatek
# 3                50               2             5              1      Mediatek
# 4                 8               2             5              1      Mediatek
# ...             ...             ...           ...            ...           ...
# 1831             48               4            16              1      Mediatek
# 1832             48               4            16              1      Mediatek
# 1833             48               4            16              1      Mediatek
# 1834             48               4            16              2      Mediatek
# 1835             16               4            32              1      Mediatek
#
# [1231 rows x 12 columns]

# %%
# Menghapus kolom 'Banyak Rating' dan 'Rating'
df = df.drop(columns=['Banyak Rating', 'Rating', 'Nama HP'])

# %% [markdown]
# # Modeling

# %%
# Mengimpor fungsi untuk membagi data menjadi data latih dan data uji.
from sklearn.model_selection import train_test_split

# Mengimpor model regresi linear.
from sklearn.linear_model import LinearRegression

# Mengimpor model decision tree regressor.
from sklearn.tree import DecisionTreeRegressor

# Mengimpor metrik evaluasi model.
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Memisahkan fitur (X) dan target (y).
X = df.drop(columns=['Price in INR'])  # Fitur adalah semua kolom kecuali 'Price in INR'
y = df['Price in INR']  # Target adalah kolom 'Price in INR'

# %%
# Melakukan One-Hot Encoding pada kolom kategorikal 'Upd_Processor'.
X_encoded = pd.get_dummies(X, columns=['Upd_Processor'], drop_first=True)

# %%
# Membagi dataset menjadi data latih (train) dan data uji (test).
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Model 1: Linear Regression
linear_model = LinearRegression()  # Membuat objek model Linear Regression
linear_model.fit(X_train, y_train)  # Melatih model pada data latih
y_pred_linear = linear_model.predict(X_test)  # Memprediksi nilai target pada data uji

# %%
# Model 2: Decision Tree Regressor
tree_model = DecisionTreeRegressor()  # Membuat objek model Decision Tree Regressor
tree_model.fit(X_train, y_train)  # Melatih model pada data latih
y_pred_tree = tree_model.predict(X_test)  # Memprediksi nilai target pada data uji

# %%
# Menghitung metrik evaluasi untuk Linear Regression.
mse_linear = mean_squared_error(y_test, y_pred_linear)  # Mean Squared Error (MSE)
mae_linear = mean_absolute_error(y_test, y_pred_linear)  # Mean Absolute Error (MAE)
rmse_linear = np.sqrt(mse_linear)  # Root Mean Squared Error (RMSE)

# %%
# Menghitung metrik evaluasi untuk Decision Tree.
mse_tree = mean_squared_error(y_test, y_pred_tree)  # Mean Squared Error (MSE)
mae_tree = mean_absolute_error(y_test, y_pred_tree)  # Mean Absolute Error (MAE)
rmse_tree = np.sqrt(mse_tree)  # Root Mean Squared Error (RMSE)

# %%
# Menampilkan hasil metrik evaluasi.
print("Linear Regression Metrics:")
print(f"MAE: {mae_linear}")
print(f"MSE: {mse_linear}")
print(f"RMSE: {rmse_linear}")

print("\nDecision Tree Metrics:")
print(f"MAE: {mae_tree}")
print(f"MSE: {mse_tree}")
print(f"RMSE: {rmse_tree}")
# Out:
# Linear Regression Metrics:
# MAE: 5713.563726860704
# MSE: 83239255.05542406
# RMSE: 9123.554957110966
#
# Decision Tree Metrics:
# MAE: 1800.9574013705594
# MSE: 14151174.667059736
# RMSE: 3761.8047087880223

# %%
# Mengimpor fungsi untuk menghitung R-squared.
from sklearn.metrics import r2_score

# Menghitung dan menampilkan R-squared untuk Linear Regression.
r2_linear = r2_score(y_test, y_pred_linear)
print(f"R² score for Linear Regression: {r2_linear}")

# Menghitung dan menampilkan R-squared untuk Decision Tree Regressor.
r2_tree = r2_score(y_test, y_pred_tree)
print(f"R² score for Decision Tree Regressor: {r2_tree}")
# Out:
# R² score for Linear Regression: 0.5906896893931103
# R² score for Decision Tree Regressor: 0.9304147821292985
